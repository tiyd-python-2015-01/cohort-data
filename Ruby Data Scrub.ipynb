# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
ruby = pd.ExcelFile("cohort_3_rails.xlsx")
print(ruby)
# Out:
# <pandas.io.excel.ExcelFile object at 0x1115511d0>

# %%
ruby.sheet_names
# Out:
# ['Lecture Score', 'HW Score']

# %%
ruby_lec = ruby.parse("Lecture Score")
ruby_lec.head()
# Out:
#     Week 1 Unnamed: 1 Unnamed: 2 Unnamed: 3 Week 2 Unnamed: 5 Unnamed: 6  \
# NaN      M          T          W         Th      M          T          W
# R01      2          2          4          3    NaN          3          5
# R02      3        3.5        4.5          4    NaN        4.5        4.5
# R03      3        4.5          4        3.5    NaN          6        4.5
# R04      2          4          4          4    NaN          5          5
#
#     Unnamed: 7 Week 3 Unnamed: 9     ...     Unnamed: 26 Unnamed: 27 Week 8  \
# NaN         Th      M          T     ...               W          Th      M
# R01          2      3          4     ...             NaN         NaN    NaN
# R02        3.5      6          4     ...             NaN         NaN    NaN
# R03          4      5          5     ...             NaN         NaN    NaN
# R04          4      5          4     ...             NaN         NaN    NaN
#
#     Unnamed: 29 Unnamed: 30 Unnamed: 31 Week 9 Unnamed: 33 Unnamed: 34  \
# NaN           T           W          Th      M           T           W
# R01         NaN         NaN         NaN    NaN         NaN         NaN
# R02         NaN         NaN         NaN    NaN         NaN         NaN
# R03         NaN         NaN         NaN    NaN         NaN         NaN
# R04         NaN         NaN         NaN    NaN         NaN         NaN
#
#     Unnamed: 35
# NaN          Th
# R01         NaN
# R02         NaN
# R03         NaN
# R04         NaN
#
# [5 rows x 36 columns]

# %%
ruby_hw = ruby.parse("HW Score")
ruby_hw.head()
# Out:
#     Week 1 Unnamed: 1 Unnamed: 2 Unnamed: 3 Week 2 Unnamed: 5 Unnamed: 6  \
# NaN      M          T          W         Th      M          T          W
# R01      4          3          3        NaN    NaN          4          3
# R02      3          4        4.5        NaN    NaN          4          4
# R03      4          4        5.5        NaN    NaN          5          4
# R04      3        4.5          3        NaN    NaN          4          4
#
#     Unnamed: 7 Week 3 Unnamed: 9     ...     Unnamed: 26 Unnamed: 27 Week 8  \
# NaN         Th      M          T     ...               W          Th      M
# R01          3      4          3     ...             NaN         NaN    NaN
# R02          4    2.5          3     ...             NaN         NaN    NaN
# R03        4.5      4          4     ...             NaN         NaN    NaN
# R04          4      4          5     ...             NaN         NaN    NaN
#
#     Unnamed: 29 Unnamed: 30 Unnamed: 31 Week 9 Unnamed: 33 Unnamed: 34  \
# NaN           T           W          Th      M           T           W
# R01         NaN         NaN         NaN    NaN         NaN         NaN
# R02         NaN         NaN         NaN    NaN         NaN         NaN
# R03         NaN         NaN         NaN    NaN         NaN         NaN
# R04         NaN         NaN         NaN    NaN         NaN         NaN
#
#     Unnamed: 35
# NaN          Th
# R01         NaN
# R02         NaN
# R03         NaN
# R04         NaN
#
# [5 rows x 36 columns]
